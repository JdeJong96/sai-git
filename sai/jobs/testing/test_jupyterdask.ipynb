# %%
import glob
import xarray as xr
from dask.distributed import Client, progress

# %%
casedir = '/gpfs/home2/jasperdj/nwo2021025/iHESP_data/HighResMIP/LR/b.e13.B1950TRC5.ne30_g16.ihesp24_2051-2100.003/'
h0files = glob.glob(casedir + 'atm/hist/*.h0.*.nc')

# %%
client = Client()

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:34389' processes=12 threads=96, memory=251.39 GiB>

# %%
h0files[0]
# Out:
# '/gpfs/home2/jasperdj/nwo2021025/iHESP_data/HighResMIP/LR/b.e13.B1950TRC5.ne30_g16.ihesp24_2051-2100.003/atm/hist/b.e13.B1950TRC5.ne30_g16.ihesp24_2051-2100.003.cam.h0.2095-08.nc'

# %%
ds = xr.open_mfdataset(h0files[:2])

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (lev: 30, time: 2, ilev: 31, cosp_prs: 7, nbnd: 2,
#                        cosp_tau: 7, cosp_scol: 50, cosp_ht: 40, cosp_sr: 15,
#                        cosp_sza: 5, ncol: 48602)
# Coordinates:
#   * lev               (lev) float64 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * ilev              (ilev) float64 2.255 5.032 10.16 ... 967.5 985.1 1e+03
#   * cosp_prs          (cosp_prs) float64 900.0 740.0 620.0 ... 375.0 245.0 90.0
#   * cosp_tau          (cosp_tau) float64 0.15 0.8 2.45 6.5 16.2 41.5 219.5
#   * cosp_scol         (cosp_scol) int32 1 2 3 4 5 6 7 8 ... 44 45 46 47 48 49 50
#   * cosp_ht           (cosp_ht) float64 240.0 720.0 ... 1.848e+04 1.896e+04
#   * cosp_sr           (cosp_sr) float64 0.605 2.1 4.0 ... 70.0 539.5 1.004e+03
#   * cosp_sza          (cosp_sza) float64 0.0 15.0 30.0 45.0 60.0
#   * time              (time) object 2074-05-01 00:00:00 2095-09-01 00:00:00
# Dimensions without coordinates: nbnd, ncol
# ...

# %%
T = ds.T.chunk({'time':2,'ncol':1000})

# %%
Tm = T.weighted(ds.area).mean('ncol')

# %%
Tm.compute()
# Out:
# <xarray.DataArray 'T' (time: 2, lev: 30)>
# array([[227.64845   , 221.66243882, 216.28400151, 211.76119899,
#         208.41210721, 205.66491689, 203.93389005, 203.82307253,
#         205.31600047, 207.41986043, 210.06481909, 213.29979026,
#         217.64258564, 223.35942876, 230.24814   , 237.95322977,
#         245.96721007, 253.94572784, 261.61827353, 268.31512632,
#         273.94332887, 277.98157662, 280.63875127, 282.3693915 ,
#         283.67856062, 285.04514546, 286.39953875, 287.72338448,
#         288.86061172, 289.57261643],
#        [223.90898085, 218.0683121 , 213.08733136, 209.70456338,
#         207.73292532, 206.18451758, 204.59534124, 204.21078088,
#         205.57570762, 207.8708836 , 210.9554513 , 214.76997441,
#         219.70702847, 226.01742724, 233.48044032, 241.48974814,
#         249.5817434 , 257.43655949, 264.81632627, 271.41863648,
#         277.00981115, 281.06370126, 283.67534087, 285.36625119,
# ...

# %%
ds2 = xr.open_mfdataset(h0files, chunks={'ncol':1000})

# %%
ds2.T
# Out:
# <xarray.DataArray 'T' (time: 372, lev: 30, ncol: 48602)>
# dask.array<concatenate, shape=(372, 30, 48602), dtype=float32, chunksize=(1, 30, 1000), chunktype=numpy.ndarray>
# Coordinates:
#   * lev      (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * time     (time) object 2070-02-01 00:00:00 ... 2101-01-01 00:00:00
# Dimensions without coordinates: ncol
# Attributes:
#     mdims:         1
#     units:         K
#     long_name:     Temperature
#     cell_methods:  time: mean

# %%
Tm = ds2.T.weighted(ds2.area).mean('ncol')

# %%
Tm.compute()
# Out:
# <xarray.DataArray 'T' (time: 372, lev: 30)>
# array([[229.39613887, 222.78854478, 216.9396155 , ..., 286.0094951 ,
#         287.10970925, 287.88977095],
#        [229.45045772, 223.00863435, 217.02923894, ..., 286.01910634,
#         287.11280771, 287.84222152],
#        [229.05012755, 222.77764762, 216.87518372, ..., 286.74961932,
#         287.85416135, 288.55026879],
#        ...,
#        [224.92165817, 219.15704882, 214.18436174, ..., 289.04761963,
#         290.24068572, 291.0671045 ],
#        [225.22684782, 219.40770521, 214.62808693, ..., 288.08761449,
#         289.26349555, 290.11070546],
#        [225.50831977, 219.44473162, 214.46841167, ..., 287.51288885,
#         288.66272516, 289.50764943]])
# Coordinates:
#   * lev      (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * time     (time) object 2070-02-01 00:00:00 ... 2101-01-01 00:00:00

# %%
client.shutdown()
